# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
import re
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
# importing the dataset
df=pd.read_csv("countries of the world.csv", decimal = ',')

# %%
df.head()
# We first take a peek of the data we read in as listing first five observations. It shows that it seems list by the alpha (first five are 'A').
# And the features, population, area ..., are showing too.
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
df.describe()
# Out:
#          Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# count  2.270000e+02    2.270000e+02                  227.000000
# mean   2.874028e+07    5.982270e+05                  379.047137
# std    1.178913e+08    1.790282e+06                 1660.185825
# min    7.026000e+03    2.000000e+00                    0.000000
# 25%    4.376240e+05    4.647500e+03                   29.150000
# 50%    4.786994e+06    8.660000e+04                   78.800000
# 75%    1.749777e+07    4.418110e+05                  190.150000
# max    1.313974e+09    1.707520e+07                16271.500000
#
#        Coastline (coast/area ratio)  Net migration  \
# count                    227.000000     224.000000
# mean                      21.165330       0.038125
# std                       72.286863       4.889269
# min                        0.000000     -20.990000
# 25%                        0.100000      -0.927500
# 50%                        0.730000       0.000000
# ...

# %%
import seaborn as sns

# %%
sns.boxplot(np.array(df['Literacy (%)']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-162359b0599f> in <module>
# ----> 1 sns.boxplot(np.array(df['Literacy (%)']))
#
# NameError: name 'np' is not defined

# %%
import seaborn as sns
import numpy as np
sns.boxplot(np.array(df['Literacy (%)']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e145d19ff1f4> in <module>
#       1 import seaborn as sns
#       2 import numpy as np
# ----> 3 sns.boxplot(np.array(df['Literacy (%)']))
#
# NameError: name 'df' is not defined

# %%
import seaborn as sns
import numpy as np
df=pd.read_csv("countries of the world.csv", decimal = ',')
sns.boxplot(np.array(df['Literacy (%)']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-848a43799305> in <module>
#       1 import seaborn as sns
#       2 import numpy as np
# ----> 3 df=pd.read_csv("countries of the world.csv", decimal = ',')
#       4 sns.boxplot(np.array(df['Literacy (%)']))
#
# NameError: name 'pd' is not defined

# %%
import seaborn as sns
import numpy as np
import pandas as pd
df=pd.read_csv("countries of the world.csv", decimal = ',')
sns.boxplot(np.array(df['Literacy (%)']))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-9ff4d46afee9> in <module>
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 df=pd.read_csv("countries of the world.csv", decimal = ',')
#       5 sns.boxplot(np.array(df['Literacy (%)']))
#
# ...

# %%
import seaborn as sns
import numpy as np
import pandas as pd
df=pd.read_csv("COTW.csv", decimal = ',')
sns.boxplot(np.array(df['Literacy (%)']))

# %% [raw]
# import seaborn as sns
# import numpy as np
# import pandas as pd
# df=pd.read_csv("COTW.csv", decimal = ',')
# df1 = df.head()
# sns.boxplot(np.array(df1['Literacy (%)']))

# %%
df1
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...
